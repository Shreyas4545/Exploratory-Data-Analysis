# %% [markdown]
# TEAM ID: D3
# SEM: 3
# DIV: D
# DEPARTMENT: COMPUTER SCIENCE

# %% [markdown]
# # PROJECT TITLE:WHY ARE SUICICDE RATE HIGH IN MALES

# %% [markdown]
# # Team Details:
# Aayushi Gupta 01fe20bcs207 (423)
# Darshan Dixit 01fe20bcs215 (431)
# Shreyas Jakati 01fe20bcs216 (432)
# Shashank hosapeti 01fe20bcs197 (413)

# %% [markdown]
# # PREPROCESSING

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn import preprocessing

# %%
#loading the data
df = pd.read_csv('marriage-rate-per-1000-inhabitants.csv')
print(df)
# Out:
#                  Entity Code  year  Crude_marriage_rate
# 0               Albania  ALB  1960                  7.8
# 1               Albania  ALB  1961                 11.3
# 2               Albania  ALB  1962                  7.5
# 3               Albania  ALB  1963                  7.5
# 4               Albania  ALB  1964                  7.2
# ...                 ...  ...   ...                  ...
# 3246            Vietnam  VNM  2002                 11.8
# 3247  Wallis and Futuna  WLF  1970                  6.3
# 3248     Western Sahara  ESH  1970                  6.6
# 3249              Yemen  YEM  2001                  0.5
# 3250              Yemen  YEM  2002                  0.6
#
# [3251 rows x 4 columns]

# %%
# viewing statistical info about dataset
df.describe()
# Out:
#               year  Crude_marriage_rate
# count  3251.000000          3251.000000
# mean   1989.635497             6.694802
# std      17.105366             2.637367
# min    1920.000000             0.200000
# 25%    1976.000000             5.100000
# 50%    1991.000000             6.500000
# 75%    2005.000000             7.950000
# max    2018.000000            59.000000

# %%
# checking for missing values
df.isnull()
# Out:
#       Entity   Code   year  Crude_marriage_rate
# 0      False  False  False                False
# 1      False  False  False                False
# 2      False  False  False                False
# 3      False  False  False                False
# 4      False  False  False                False
# ...      ...    ...    ...                  ...
# 3246   False  False  False                False
# 3247   False  False  False                False
# 3248   False  False  False                False
# 3249   False  False  False                False
# 3250   False  False  False                False
#
# [3251 rows x 4 columns]

# %%
# checking the number of missing data
df.isnull().sum()
# Out:
# Entity                   0
# Code                   103
# year                     0
# Crude_marriage_rate      0
# dtype: int64

# %%
#checking a column's missing value
code = pd.isnull(df["Code"]) 
df[code]
# Out:
#                              Entity Code  year  Crude_marriage_rate
# 944   European Union (28 countries)  NaN  1964                  7.9
# 945   European Union (28 countries)  NaN  1965                  7.8
# 946   European Union (28 countries)  NaN  1966                  7.8
# 947   European Union (28 countries)  NaN  1967                  7.8
# 948   European Union (28 countries)  NaN  1968                  7.7
# ...                             ...  ...   ...                  ...
# 1138          France (metropolitan)  NaN  2011                  3.7
# 1139          France (metropolitan)  NaN  2012                  3.7
# 2581       Saint Pierre et Miquelon  NaN  1970                  5.9
# 2582       Saint Pierre et Miquelon  NaN  1984                  5.3
# 2583       Saint Pierre et Miquelon  NaN  1996                  4.5
#
# [103 rows x 4 columns]

# %%
# percentage of null values in the datset
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# Entity                 0.000000
# Code                   3.168256
# year                   0.000000
# Crude_marriage_rate    0.000000
# dtype: float64

# %%
print("dropping only the country Code as it doesn't play any vital role in the data analysis of the given dataset")
df.drop(['Code'], axis = 1,inplace = True)
# Out:
# dropping only the country Code as it doesn't play any vital role in the data analysis of the given dataset

# %%
df.isnull().sum()
# Out:
# Entity                 0
# year                   0
# Crude_marriage_rate    0
# dtype: int64

# %%
df.head()
# Out:
#     Entity  year  Crude_marriage_rate
# 0  Albania  1960                  7.8
# 1  Albania  1961                 11.3
# 2  Albania  1962                  7.5
# 3  Albania  1963                  7.5
# 4  Albania  1964                  7.2

# %%
# # Start Code
df['Crude_marriage_rate'] = (df['Crude_marriage_rate']-df['Crude_marriage_rate'].mean())/df['Crude_marriage_rate'].std()
df['Crude_marriage_rate'].std()
# Out:
# 0.9999999999999984

# %%
# copy the data
df_max_scaled = df.copy()

# apply normalization techniques
for column in df_max_scaled.columns:df_max_scaled['Crude_marriage_rate'] = df_max_scaled['Crude_marriage_rate'] / df_max_scaled['Crude_marriage_rate'].abs().max()

# view normalized data
display(df_max_scaled.head())
display(df_max_scaled.tail())
# Out:
#     Entity  year  Crude_marriage_rate
# 0  Albania  1960             0.021130
# 1  Albania  1961             0.088045
# 2  Albania  1962             0.015394
# 3  Albania  1963             0.015394
# 4  Albania  1964             0.009659
#                  Entity  year  Crude_marriage_rate
# 3246            Vietnam  2002             0.097604
# 3247  Wallis and Futuna  1970            -0.007548
# 3248     Western Sahara  1970            -0.001812
# 3249              Yemen  2001            -0.118436
# 3250              Yemen  2002            -0.116524

# %%
print("The one with deeper color are highly correlated\n")
#Using Pearson Correlation

plt.figure(figsize=(4,4))
correlation = df.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Blues)
plt.show()
# Out:
# The one with deeper color are highly correlated

# %%
#loading the data
df1=pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
df1
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
# viewing statistical info about dataset
df1.describe()
# Out:
#               year  Average_of_depression_prevalance_in_males  \
# count    28.000000                                  28.000000
# mean   2003.500000                                   2.688371
# std       8.225975                                   0.019857
# min    1990.000000                                   2.631965
# 25%    1996.750000                                   2.682035
# 50%    2003.500000                                   2.689537
# 75%    2010.250000                                   2.696545
# max    2017.000000                                   2.723878
#
#        Average_of_Male_suicide_rate (age-standardized)
# count                                        28.000000
# mean                                         18.806597
# std                                           1.368696
# min                                          16.422896
# 25%                                          17.627330
# 50%                                          19.212557
# ...

# %%
# checking for missing values
df1.isnull()
# Out:
#      year  Average_of_depression_prevalance_in_males  \
# 0   False                                      False
# 1   False                                      False
# 2   False                                      False
# 3   False                                      False
# 4   False                                      False
# 5   False                                      False
# 6   False                                      False
# 7   False                                      False
# 8   False                                      False
# 9   False                                      False
# 10  False                                      False
# 11  False                                      False
# 12  False                                      False
# 13  False                                      False
# 14  False                                      False
# 15  False                                      False
# 16  False                                      False
# ...

# %%
# checking the number of missing data
df1.isnull().sum()
# Out:
# year                                               0
# Average_of_depression_prevalance_in_males          0
# Average_of_Male_suicide_rate (age-standardized)    0
# dtype: int64

# %%
print("there are no null values in this dataset")
# Out:
# there are no null values in this dataset

# %%
# Normalizing the value of the dataset
df_z_scaled = df1.copy()

for column in df_z_scaled.columns:df_z_scaled['Average_of_depression_prevalance_in_males'] = (df_z_scaled['Average_of_depression_prevalance_in_males']-df_z_scaled['Average_of_depression_prevalance_in_males'].mean()) / df_z_scaled['Average_of_depression_prevalance_in_males'].std()
for column in df_z_scaled.columns:df_z_scaled['Average_of_Male_suicide_rate (age-standardized)'] = (df_z_scaled['Average_of_Male_suicide_rate (age-standardized)']-df_z_scaled['Average_of_Male_suicide_rate (age-standardized)'].mean()) / df_z_scaled['Average_of_Male_suicide_rate (age-standardized)'].std()

display(df_z_scaled)
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                  -0.312992
# 1   1991                                  -0.337333
# 2   1992                                  -0.385271
# 3   1993                                  -0.085484
# 4   1994                                   0.506360
# 5   1995                                   0.341667
# 6   1996                                  -0.831164
# 7   1997                                   0.380120
# 8   1998                                   1.788174
# 9   1999                                   0.033130
# 10  2000                                  -0.229734
# 11  2001                                  -0.206149
# 12  2002                                   1.151629
# 13  2003                                   0.339633
# 14  2004                                   0.711425
# 15  2005                                   0.735805
# 16  2006                                   0.324674
# ...

# %%
# df1['points_bin'] = pd.qcut(df1['Average_of_depression_prevalance_in_males'], q=4)
# df1
# df1['Average_of_depression_prevalance_in_males'].max()

# %%
# df1['points_bin'].value_counts()

# %%
print("The one with deeper color are highly correlated\n")
#Using Pearson Correlation

plt.figure(figsize=(4,4))
correlation = df1.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Reds)
plt.show()
# Out:
# The one with deeper color are highly correlated

# %%
# loading the data
df1 = pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
# df1=df1.drop(['Average_of_Male_suicide_rate_(age-standardized)'], axis = 1)
df1
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
df2=pd.read_csv('male-vs-female-suicide.csv')
#df2=df2.drop(['Average_of_Male_suicide_rate (age-standardized)'], axis = 1)
df2
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                        18.705217
# 1   1991                                        18.847283
# 2   1992                                        19.145870
# 3   1993                                        19.692065
# 4   1994                                        20.053587
# 5   1995                                        20.115652
# 6   1996                                        19.842283
# 7   1997                                        19.724457
# 8   1998                                        19.682174
# 9   1999                                        19.549891
# 10  2000                                        19.485652
# 11  2001                                        19.348804
# 12  2002                                        19.196522
# 13  2003                                        19.011848
# 14  2004                                        18.756522
# ...

# %%
df_final = df2.merge(df1, left_on = 'year', right_on = 'year')
df_final
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                        18.705217
# 1   1991                                        18.847283
# 2   1992                                        19.145870
# 3   1993                                        19.692065
# 4   1994                                        20.053587
# 5   1995                                        20.115652
# 6   1996                                        19.842283
# 7   1997                                        19.724457
# 8   1998                                        19.682174
# 9   1999                                        19.549891
# 10  2000                                        19.485652
# 11  2001                                        19.348804
# 12  2002                                        19.196522
# 13  2003                                        19.011848
# 14  2004                                        18.756522
# ...

# %%
# plt.xticks(rotation=90)
# Year = df_final['Year'].tolist()
# plt.plot(Year,df_final['Average_of_Male_suicide_rate_(age-standardized)'],color="red",linewidth = '2.5',marker='o')
# plt.title('Average of Male suicide rate (age-standardized) vs year')
# plt.xlabel('Year')
# plt.ylabel('Average_of_Male_suicide_rate_(age-standardized)')
# plt.grid()
# plt.show()

# %%
plt.xticks(rotation=90)
Year = df_final['year'].tolist()
plt.plot(Year,df_final['Average_of_depression_prevalance_in_males'],color="red",linewidth = '2.5',marker='o')
plt.title('Average_of_depression_prevalance_in_males vs year')
plt.xlabel('year')
plt.ylabel('Average_of_depression_prevalance_in_males')
plt.grid()
plt.show()

# %%
print("The one with deeper color are highly correlated\n")
#Using Pearson Correlation

plt.figure(figsize=(4,4))
correlation = df_final.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Reds)
plt.show()
# Out:
# The one with deeper color are highly correlated

# %% [markdown]
# # CONCATENATING TWO DATASETS

# %%
df1 = pd.read_csv('prevalence_by_mental_and_substa.csv')
df1=df1.drop(['entity', 'code'], axis = 1)
df1=df1.groupby('year').sum()
df1
# Out:
#       schizophrenia  bipolar_disorder  eating_disorders  anxiety_disorders  \
# year
# 1990      48.405538        165.255610         51.229782         914.129204
# 1991      48.414451        165.335866         51.299488         914.762138
# 1992      48.425396        165.416999         51.393084         915.401798
# 1993      48.438410        165.495384         51.520546         916.008639
# 1994      48.452425        165.570461         51.677011         916.602536
# 1995      48.466053        165.635450         51.862720         917.081743
# 1996      48.481578        165.694686         52.109217         917.732732
# 1997      48.502217        165.757379         52.432420         918.787986
# 1998      48.527353        165.821781         52.802224         920.012699
# 1999      48.556096        165.885010         53.191032         921.149890
# 2000      48.587379        165.943613         53.554683         921.918922
# ...

# %%
# LOADING THE DATA
df2=pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
df2
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
# merging the two datasets
df_final = df2.merge(df1, left_on = 'year', right_on = 'year')
df_final
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
anxiety = df_final.sort_values('anxiety_disorders',ascending=True)
anxiety.head(30)
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
depression = df_final.sort_values('Average_of_Male_suicide_rate (age-standardized)',ascending=False)
depression_top = depression.head()
depression_top
# Out:
#    year  Average_of_depression_prevalance_in_males  \
# 5  1995                                   2.695155
# 4  1994                                   2.698425
# 6  1996                                   2.671866
# 7  1997                                   2.695919
# 8  1998                                   2.723878
#
#    Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 5                                        20.595204      48.466053
# 4                                        20.461765      48.452425
# 6                                        20.400045      48.481578
# 7                                        20.297873      48.502217
# 8                                        20.251946      48.527353
#
#    bipolar_disorder  eating_disorders  anxiety_disorders  drug_use_disorders  \
# 5        165.635450         51.862720         917.081743          192.282285
# 4        165.570461         51.677011         916.602536          191.357771
# ...

# %%
schizophrenia = df_final.sort_values('schizophrenia',ascending=True)
schizophrenia.head(10)
# schizophrenia doesnt much contributes ,
# Out:
#    year  Average_of_depression_prevalance_in_males  \
# 0  1990                                   2.682156
# 1  1991                                   2.681672
# 2  1992                                   2.680720
# 3  1993                                   2.686673
# 4  1994                                   2.698425
# 5  1995                                   2.695155
# 6  1996                                   2.671866
# 7  1997                                   2.695919
# 8  1998                                   2.723878
# 9  1999                                   2.689029
#
#    Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 0                                        19.247149      48.405538
# 1                                        19.369186      48.414451
# 2                                        19.629005      48.425396
# 3                                        20.088145      48.438410
# 4                                        20.461765      48.452425
# ...

# %%
bipolar_disorder = df_final.sort_values('bipolar_disorder',ascending=False)
bipolar_disorder.head(10)
# bipolar_disorder doesnt much contributes ,
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 27  2017                                   2.719256
# 26  2016                                   2.690045
# 25  2015                                   2.631965
# 24  2014                                   2.669719
# 23  2013                                   2.688832
# 22  2012                                   2.688392
# 21  2011                                   2.692987
# 20  2010                                   2.714296
# 19  2009                                   2.651756
# 18  2008                                   2.654254
#
#     Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 27                                        16.422896      49.596879
# 26                                        16.533439      49.552084
# 25                                        16.691855      49.505607
# 24                                        16.778824      49.458288
# ...

# %%
eating_disorders = df_final.sort_values('eating_disorders',ascending=True)
eating_disorders.head(10)
# eating_disorders doesnt much contributes ,
# Out:
#    year  Average_of_depression_prevalance_in_males  \
# 0  1990                                   2.682156
# 1  1991                                   2.681672
# 2  1992                                   2.680720
# 3  1993                                   2.686673
# 4  1994                                   2.698425
# 5  1995                                   2.695155
# 6  1996                                   2.671866
# 7  1997                                   2.695919
# 8  1998                                   2.723878
# 9  1999                                   2.689029
#
#    Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 0                                        19.247149      48.405538
# 1                                        19.369186      48.414451
# 2                                        19.629005      48.425396
# 3                                        20.088145      48.438410
# 4                                        20.461765      48.452425
# ...

# %%
drug_use_disorders = df_final.sort_values('drug_use_disorders',ascending=False)
drug_use_disorders.head(10)
# drug_use_disorders doesnt much contributes ,
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 27  2017                                   2.719256
# 26  2016                                   2.690045
# 25  2015                                   2.631965
# 24  2014                                   2.669719
# 23  2013                                   2.688832
# 22  2012                                   2.688392
# 21  2011                                   2.692987
# 20  2010                                   2.714296
# 19  2009                                   2.651756
# 18  2008                                   2.654254
#
#     Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 27                                        16.422896      49.596879
# 26                                        16.533439      49.552084
# 25                                        16.691855      49.505607
# 24                                        16.778824      49.458288
# ...

# %%
alcohol_use_disorders = df_final.sort_values('alcohol_use_disorders',ascending=False)
alcohol_use_disorders.head(10)
# alcohol_use_disorders doesnt much contributes , 
# as alcohol_use_disorders is not at the peak in 1995 , it increases gradually as the year passes.
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 20  2010                                   2.714296
# 21  2011                                   2.692987
# 22  2012                                   2.688392
# 23  2013                                   2.688832
# 19  2009                                   2.651756
# 24  2014                                   2.669719
# 25  2015                                   2.631965
# 18  2008                                   2.654254
# 26  2016                                   2.690045
# 17  2007                                   2.692649
#
#     Average_of_Male_suicide_rate (age-standardized)  schizophrenia  \
# 20                                        17.692081      49.273738
# 21                                        17.433077      49.317770
# 22                                        17.202489      49.363843
# 23                                        16.961131      49.410925
# ...

# %%
plt.figure(figsize=(4,4))
correlation = df_final.corr()
plt.figure(figsize=(10,10))
#finding the correlation between the different attributes of the concatenated dataset
sns.heatmap(correlation, annot=True, cmap=plt.cm.Blues)
plt.show()

# %%
# regression plot
sns.regplot(x="drug_use_disorders",y="bipolar_disorder",data=depression_top)
plt.ylim()
# Out:
# (165.55517005024566, 165.89157517566045)

# %% [raw]
# ANALYSIS 1:
# >DEPRESSION AND AVERAGE MALE SUICIDE RATE ARE STRONGLY CORRELATED (0.98),
# >ALSO DEPRESSION RATE DECREASES GRADUALLY YEAR BY YEAR , SO IS THE AVERAGE MALE SUICIDE RATE
# >SO AS THE YEARS PASSES, DEPRESSION IS NOT THE MOST COMMON REASON FOR MALES TO  COMMIT SUICIDE, OTHER DISORDER SUCH AS alcohol_use_disorders, schizophrenia ,ETC CONTIBUTES MORE TO AVERAGE MALE SUICIDE RATE

# %% [raw]
# ANALYSIS 2:
# >SECOND MOST CONTRIBUITING DISORDER IS anxiety_disorders WHICH IS POSITIVELY COREELATED WITH AVERAGE MALE SUICIDE RATE,
# >BUT anxiety_disorders INCREASES YEAR BY YEAR , BUT AVERAGE MALE SUICIDE RATE IS DECREASING , IE. anxiety_disorders DOESN'T CONTRIBUTES MORE COMPARE TO OTHER MENTAL DISORDERS

# %% [markdown]
# # concatinating the crude marriage rate and male vs female average suicide rate

# %%
# LOADING THE DATA
df = pd.read_csv('marriage-rate-per-1000-inhabitants.csv')
df
# Out:
#                  Entity Code  year  Crude_marriage_rate
# 0               Albania  ALB  1960                  7.8
# 1               Albania  ALB  1961                 11.3
# 2               Albania  ALB  1962                  7.5
# 3               Albania  ALB  1963                  7.5
# 4               Albania  ALB  1964                  7.2
# ...                 ...  ...   ...                  ...
# 3246            Vietnam  VNM  2002                 11.8
# 3247  Wallis and Futuna  WLF  1970                  6.3
# 3248     Western Sahara  ESH  1970                  6.6
# 3249              Yemen  YEM  2001                  0.5
# 3250              Yemen  YEM  2002                  0.6
#
# [3251 rows x 4 columns]

# %%
# GROUPING THE DATA YEAR-WISE
df=df.groupby(['year']).sum()     
df
# Out:
#       Crude_marriage_rate
# year
# 1920                 12.0
# 1921                 10.7
# 1922                 10.3
# 1923                 11.0
# 1924                 10.4
# ...                   ...
# 2014                259.1
# 2015                278.7
# 2016                271.0
# 2017                249.1
# 2018                  6.5
#
# [99 rows x 1 columns]

# %%
df1 = df.iloc[70:98]
df1
# Out:
#       Crude_marriage_rate
# year
# 1990           316.000000
# 1991           291.700000
# 1992           333.100000
# 1993           319.600001
# 1994           303.600000
# 1995           851.800000
# 1996           322.700001
# 1997           302.699999
# 1998           278.900000
# 1999           301.600000
# 2000           331.300001
# 2001           289.600000
# 2002           300.200001
# 2003           346.300000
# 2004           480.400002
# 2005           778.000003
# 2006           618.199999
# 2007           445.400000
# 2008           339.600000
# 2009           308.000000
# 2010           303.700000
# 2011           306.500000
# 2012           283.900000
# 2013           254.600000
# 2014           259.100000
# 2015           278.700000
# 2016           271.000000
# 2017           249.100000

# %%
# LOADING THE DATA
df2 = pd.read_csv('male-vs-female-suicide.csv')

# %%
# MERGING THE TWO DATASETS ON THE COMMON ATTRIBUTE YEAR
merged_data = df1.merge(df2,on=["year"])
merged_data
# merged_data.info()
# Out:
#     year  Crude_marriage_rate  \
# 0   1990           316.000000
# 1   1991           291.700000
# 2   1992           333.100000
# 3   1993           319.600001
# 4   1994           303.600000
# 5   1995           851.800000
# 6   1996           322.700001
# 7   1997           302.699999
# 8   1998           278.900000
# 9   1999           301.600000
# 10  2000           331.300001
# 11  2001           289.600000
# 12  2002           300.200001
# 13  2003           346.300000
# 14  2004           480.400002
# 15  2005           778.000003
# 16  2006           618.199999
# 17  2007           445.400000
# 18  2008           339.600000
# 19  2009           308.000000
# 20  2010           303.700000
# 21  2011           306.500000
# 22  2012           283.900000
# 23  2013           254.600000
# 24  2014           259.100000
# 25  2015           278.700000
# 26  2016           271.000000
# 27  2017           249.100000
#
#     Average of Male suicide rate (age-standardized)  \
# ...

# %%
#normalizing the concatenated dataset
df_z_scaled = merged_data.copy()

for column in df_z_scaled.columns:df_z_scaled['Crude_marriage_rate'] = (df_z_scaled['Crude_marriage_rate']-df_z_scaled['Crude_marriage_rate'].mean()) / df_z_scaled['Crude_marriage_rate'].std()

# for column in df_z_scaled.columns:df_z_scaled['Average_of_Female_suicide_rate_(age-standardized)'] = (df_z_scaled['Average_of_Female_suicide_rate_(age-standardized)']-df_z_scaled['Average_of_Female_suicide_rate_(age-standardized)'].mean()) / df_z_scaled['Average_of_Female_suicide_rate_(age-standardized)'].std()
for column in df_z_scaled.columns:df_z_scaled['Average of Male suicide rate (age-standardized)'] = (df_z_scaled['Average of Male suicide rate (age-standardized)']-df_z_scaled['Average of Male suicide rate (age-standardized)'].mean()) / df_z_scaled['Average of Male suicide rate (age-standardized)'].std()

# SINCE WE ARE ONLY INTRESTEDIN ANALYSISNG THE MALE SUICIDE  RATE , WE CAN DROP THE Average_of_Female_suicide_rate_(age-standardized) COLUMN
display(df_z_scaled)
# Out:
#     year  Crude_marriage_rate  \
# 0   1990            -0.290565
# 1   1991            -0.452973
# 2   1992            -0.176277
# 3   1993            -0.266504
# 4   1994            -0.373440
# 5   1995             3.290447
# 6   1996            -0.245785
# 7   1997            -0.379455
# 8   1998            -0.538522
# 9   1999            -0.386807
# 10  2000            -0.188307
# 11  2001            -0.467009
# 12  2002            -0.396164
# 13  2003            -0.088055
# 14  2004             0.808200
# 15  2005             2.797206
# 16  2006             1.729185
# 17  2007             0.574278
# 18  2008            -0.132834
# 19  2009            -0.344032
# 20  2010            -0.372771
# 21  2011            -0.354058
# 22  2012            -0.505104
# 23  2013            -0.700930
# 24  2014            -0.670855
# 25  2015            -0.539859
# 26  2016            -0.591321
# 27  2017            -0.737690
#
#     Average of Male suicide rate (age-standardized)  \
# ...

# %% [raw]
# clearly, higher the crude marriage rate , higher the suicide rate.

# %%
print("The one with deeper color are highly correlated\n")
#Using Pearson Correlation

plt.figure(figsize=(4,4))
correlation = df_z_scaled.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Blues)
plt.show()
# Out:
# The one with deeper color are highly correlated

# %%
# loading the data
crude=pd.read_csv('marriage-rate-per-1000-inhabitants.csv')

# %%
# grouping the tuples on the year
#crude=crude.drop(['entity', 'code'], axis = 1)
crude=crude.groupby('year').sum()
crude
# Out:
#       Crude_marriage_rate
# year
# 1920                 12.0
# 1921                 10.7
# 1922                 10.3
# 1923                 11.0
# 1924                 10.4
# ...                   ...
# 2014                259.1
# 2015                278.7
# 2016                271.0
# 2017                249.1
# 2018                  6.5
#
# [99 rows x 1 columns]

# %%
# dropping the tuples with year less than 1990 and greater tha 2017
crude = crude.drop(crude.index[range(1990-1920)])
crude=crude.drop(crude.index[-1])

# %%
plt.plot(Year, crude["Crude_marriage_rate"], color="blue", linewidth=3.0)
plt.xlabel("year")
plt.ylabel("Crude_marriage_rate")
plt.title("Crude_marriage_rate_(per 1000 inhabitants) vs Year")
plt.show()

# %%
# sorting the values
c=crude.sort_values(by="Crude_marriage_rate",ascending=False)
c
# Out:
#       Crude_marriage_rate
# year
# 1995           851.800000
# 2005           778.000003
# 2006           618.199999
# 2004           480.400002
# 2007           445.400000
# 2003           346.300000
# 2008           339.600000
# 1992           333.100000
# 2000           331.300001
# 1996           322.700001
# 1993           319.600001
# 1990           316.000000
# 2009           308.000000
# 2011           306.500000
# 2010           303.700000
# 1994           303.600000
# 1997           302.699999
# 1999           301.600000
# 2002           300.200001
# 1991           291.700000
# 2001           289.600000
# 2012           283.900000
# 1998           278.900000
# 2015           278.700000
# 2016           271.000000
# 2014           259.100000
# 2013           254.600000
# 2017           249.100000

# %% [raw]
# ANALYSIS 3:
# >From the dataset- MALE-VS-FEMALE-SUICIDE DATASET ANALYSIS, AVERAGE MALE SUICIDE RATE IS HIGHEST IN THE YAER 1995
# >IGNORING THE 1970 AND 1985 DATA ,AS WE ARE PROVIDED WITH THE DATA FROM THE YEAR 1990 TO THE YEAR 2017 IN TH EITHER DATASETS
# >SO WE CAN SAY THAT FOR THE GIVEN YEARS OF THE DATS 1995 HAS THE HIGHEST CRUDE MARRIAGE RATE, ALSO WE GOT INFERENCE FROM THE ANALYSIS THAT IN THE YEAR 1995 AVERAGE MALE SUICIDE RATE WAS HIGHEST

# %% [raw]
# ANALYSIS 4:
# >ALSO, CRUDE MARRIAGE RATE IS DECREASING GRADUALLY YERA BY YEAR , SO IS THE AVERAGE MALE SUICIDE RATE .
# >HENCEFORTH CRUDE MARRIAGE RATE AND AVERAGE MALE SUICIDE RATE ARE DIRECTLY PROPOPTIONAL TO EACH OTHER.

# %%
# load the data
df1 = pd.read_csv('./male-vs-female-suicide.csv')
df1
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                        18.705217
# 1   1991                                        18.847283
# 2   1992                                        19.145870
# 3   1993                                        19.692065
# 4   1994                                        20.053587
# 5   1995                                        20.115652
# 6   1996                                        19.842283
# 7   1997                                        19.724457
# 8   1998                                        19.682174
# 9   1999                                        19.549891
# 10  2000                                        19.485652
# 11  2001                                        19.348804
# 12  2002                                        19.196522
# 13  2003                                        19.011848
# 14  2004                                        18.756522
# ...

# %%
# using pearson method to normalize the data
#normalizing the concatenated dataset
df_z_scaled = df1.copy()

# for column in df_z_scaled.columns:df_z_scaled['Crude_marriage_rate_(per 1000 inhabitants)'] = (df_z_scaled['Crude_marriage_rate_(per 1000 inhabitants)']-df_z_scaled['Crude_marriage_rate_(per 1000 inhabitants)'].mean()) / df_z_scaled['Crude_marriage_rate_(per 1000 inhabitants)'].std()
for column in df_z_scaled.columns:df_z_scaled['Average of Female suicide rate (age-standardized)'] = (df_z_scaled['Average of Female suicide rate (age-standardized)']-df_z_scaled['Average of Female suicide rate (age-standardized)'].mean()) / df_z_scaled['Average of Female suicide rate (age-standardized)'].std()
for column in df_z_scaled.columns:df_z_scaled['Average of Male suicide rate (age-standardized)'] = (df_z_scaled['Average of Male suicide rate (age-standardized)']-df_z_scaled['Average of Male suicide rate (age-standardized)'].mean()) / df_z_scaled['Average of Male suicide rate (age-standardized)'].std()

display(df_z_scaled)
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                         0.243956
# 1   1991                                         0.350532
# 2   1992                                         0.574529
# 3   1993                                         0.984279
# 4   1994                                         1.255489
# 5   1995                                         1.302050
# 6   1996                                         1.096971
# 7   1997                                         1.008579
# 8   1998                                         0.976859
# 9   1999                                         0.877622
# 10  2000                                         0.829430
# 11  2001                                         0.726768
# 12  2002                                         0.612527
# 13  2003                                         0.473987
# 14  2004                                         0.282444
# ...

# %%
print("The one with deeper color are highly correlated\n")
#Using Pearson Correlation

plt.figure(figsize=(4,4))
correlation = df_z_scaled.corr()
sns.heatmap(correlation, annot=True, cmap=plt.cm.Greens)
plt.show()
# Out:
# The one with deeper color are highly correlated

# %%
df = pd.read_csv('prevalence_by_mental_and_substa.csv')
bel = df[df.entity == 'Belarus']
bel
# Out:
#       entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 504  Belarus  BLR  1990       0.191284          0.693581          0.174512
# 505  Belarus  BLR  1991       0.191159          0.693487          0.172050
# 506  Belarus  BLR  1992       0.191010          0.693393          0.169549
# 507  Belarus  BLR  1993       0.190855          0.693328          0.167731
# 508  Belarus  BLR  1994       0.190705          0.693289          0.165887
# 509  Belarus  BLR  1995       0.190561          0.693234          0.164067
# 510  Belarus  BLR  1996       0.190335          0.693205          0.162738
# 511  Belarus  BLR  1997       0.189994          0.693224          0.161153
# 512  Belarus  BLR  1998       0.189640          0.693293          0.160119
# 513  Belarus  BLR  1999       0.189372          0.693396          0.159517
# 514  Belarus  BLR  2000       0.189298          0.693549          0.159122
# ...

# %%
plt.plot(bel.year, bel["alcohol_use_disorders"], color="blue")
plt.xlabel("year")
plt.ylabel("alcohol_use_disorders")
plt.title("Year-wise comparison of alcohol_use_disorders")
plt.show()

# %%
# loading the data
df3=pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
df3
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
boxplot = df3.boxplot(figsize=(15,10), rot=90,column=['Average_of_depression_prevalance_in_males', 'Average_of_Male_suicide_rate (age-standardized)'])

# %%
    Q1=df3.quantile(0.25)
    Q3=df3.quantile(0.75)
    IQR=Q3-Q1
    IQR
# Out:
# year                                               13.500000
# Average_of_depression_prevalance_in_males           0.014511
# Average_of_Male_suicide_rate (age-standardized)     2.366233
# dtype: float64

# %%
df_final=df3.dropna(axis=0, how='any')
df_final
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
df_max_scaled = df_final.copy()
  
# apply normalization techniques 
column = 'Average_of_depression_prevalance_in_males'
df_max_scaled[column] = df_max_scaled[column] /df_max_scaled[column].abs().max()

column1 = 'Average_of_Male_suicide_rate (age-standardized)'
df_max_scaled[column1] = df_max_scaled[column1] /df_max_scaled[column1].abs().max()

  
# view normalized data
display(df_max_scaled)
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   0.984683
# 1   1991                                   0.984505
# 2   1992                                   0.984156
# 3   1993                                   0.986341
# 4   1994                                   0.990656
# 5   1995                                   0.989455
# 6   1996                                   0.980905
# 7   1997                                   0.989735
# 8   1998                                   1.000000
# 9   1999                                   0.987206
# 10  2000                                   0.985290
# 11  2001                                   0.985462
# 12  2002                                   0.995360
# 13  2003                                   0.989440
# 14  2004                                   0.992151
# 15  2005                                   0.992328
# 16  2006                                   0.989331
# ...

# %%
plt.plot(df_max_scaled["year"], df_max_scaled["Average_of_Male_suicide_rate (age-standardized)"]/df_max_scaled["Average_of_Male_suicide_rate (age-standardized)"].iloc[0] * 100, color="blue")
plt.plot(df_max_scaled["year"], df_max_scaled["Average_of_depression_prevalance_in_males"]/df_max_scaled["Average_of_depression_prevalance_in_males"].iloc[0] * 100, color="red")
plt.legend(['Average_of_Male_suicide_rate (age-standardized)', 'Average_of_depression_prevalance_in_males'])
plt.xlabel("year")
plt.title("Year-wise comparison of alcohol_use_disorders")
plt.show()

# %% [markdown]
# # WHICH COUNTRY HAS HIGHEST AVERAGE MALE SUICIDE RATE

# %%
df1=pd.read_csv('prevalence_by_mental_and_substa.csv')
df4=pd.read_csv('marriage-rate-per-1000-inhabitants.csv')

df4=df4.groupby(['year']).sum()
df5 = df4.iloc[70:98]
df5
df1=df1.groupby(['year','code']).sum()

# %%
res1 = pd.merge(df1, df5, how='right', on=['year'])

highdep=res1[res1.depression == res1["depression"].max()]
highdep
# Out:
#       schizophrenia  bipolar_disorder  eating_disorders  anxiety_disorders  \
# year
# 1995       0.315753          0.590903           0.47654           5.648279
#
#       drug_use_disorders  depression  alcohol_use_disorders  \
# year
# 1995            1.678836    6.602754               3.489129
#
#       Crude_marriage_rate
# year
# 1995                851.8

# %%
#max depression = 6.602754 and cmr = 851.8

# %%
dep = pd.read_csv('prevalence_by_mental_and_substa.csv')
maxSuic = dep[dep.depression == dep["depression"].max()]
maxSuic
#all the numbers are exactly same as "highdep" so Greenland has max avg male suicide rate
# Out:
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903           0.47654
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 2245           5.648279            1.678836    6.602754               3.489129

# %%
correlation = res1.corr(method='pearson')
correlation
# Out:
#                        schizophrenia  bipolar_disorder  eating_disorders  \
# schizophrenia               1.000000          0.234892          0.684696
# bipolar_disorder            0.234892          1.000000          0.704019
# eating_disorders            0.684696          0.704019          1.000000
# anxiety_disorders           0.469624          0.654033          0.676402
# drug_use_disorders          0.405126          0.348262          0.420564
# depression                  0.125711          0.111643          0.193994
# alcohol_use_disorders      -0.044424          0.062198          0.031973
# Crude_marriage_rate        -0.008323         -0.002234         -0.016559
#
#                        anxiety_disorders  drug_use_disorders  depression  \
# schizophrenia                   0.469624            0.405126    0.125711
# bipolar_disorder                0.654033            0.348262    0.111643
# eating_disorders                0.676402            0.420564    0.193994
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
df=pd.read_csv('prevalence_by_mental_and_substa.csv')
d = df[df.year==1995]
d["total"]=d["schizophrenia"] + d["bipolar_disorder"] + d["eating_disorders"] + d["anxiety_disorders"] + d["drug_use_disorders"] + d["depression"] + d["alcohol_use_disorders"]
d
# Out:
# /var/folders/01/858tkgy52j77xxqjvsnjjkdc0000gn/T/ipykernel_34762/459731238.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["total"]=d["schizophrenia"] + d["bipolar_disorder"] + d["eating_disorders"] + d["anxiety_disorders"] + d["drug_use_disorders"] + d["depression"] + d["alcohol_use_disorders"]
#                           entity      code  year  schizophrenia  \
# 5                    Afghanistan       AFG  1995       0.160076
# 33                       Albania       ALB  1995       0.193559
# 61                       Algeria       DZA  1995       0.192458
# 89                American Samoa       ASM  1995       0.249678
# 117         Andean Latin America       NaN  1995       0.195637
# ...

# %%
t = d[d.total == d["total"].max()]
t
# Out:
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903           0.47654
#
#       anxiety_disorders  drug_use_disorders  depression  \
# 2245           5.648279            1.678836    6.602754
#
#       alcohol_use_disorders      total
# 2245               3.489129  18.802194

# %%
greenland = d.loc[(d['code']=='GRL') & (d['year']==1995)]
values = greenland.iloc[:, 3:10].copy()
labels = values.columns
values = values.squeeze()


fig, ax = plt.subplots()


ax.pie(values, labels=labels, autopct='%1.1f%%')


ax.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Further analysis on mental disorders

# %%
df1 = pd.read_csv("male-vs-female-suicide.csv")
df2 = pd.read_csv("prevalence_by_mental_and_substa.csv")
df2.drop(['entity', 'code'], axis = 1)
df2=df2.groupby("year").sum()
df2
# Out:
#       schizophrenia  bipolar_disorder  eating_disorders  anxiety_disorders  \
# year
# 1990      48.405538        165.255610         51.229782         914.129204
# 1991      48.414451        165.335866         51.299488         914.762138
# 1992      48.425396        165.416999         51.393084         915.401798
# 1993      48.438410        165.495384         51.520546         916.008639
# 1994      48.452425        165.570461         51.677011         916.602536
# 1995      48.466053        165.635450         51.862720         917.081743
# 1996      48.481578        165.694686         52.109217         917.732732
# 1997      48.502217        165.757379         52.432420         918.787986
# 1998      48.527353        165.821781         52.802224         920.012699
# 1999      48.556096        165.885010         53.191032         921.149890
# 2000      48.587379        165.943613         53.554683         921.918922
# ...

# %%
res1 = pd.merge(df1, df2, how='right', on=['year'])
res1["total"] = res1["schizophrenia"] + res1["bipolar_disorder"] + res1["eating_disorders"] + res1["anxiety_disorders"] + res1["drug_use_disorders"] + res1["depression"] + res1["alcohol_use_disorders"]
res1
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                        18.705217
# 1   1991                                        18.847283
# 2   1992                                        19.145870
# 3   1993                                        19.692065
# 4   1994                                        20.053587
# 5   1995                                        20.115652
# 6   1996                                        19.842283
# 7   1997                                        19.724457
# 8   1998                                        19.682174
# 9   1999                                        19.549891
# 10  2000                                        19.485652
# 11  2001                                        19.348804
# 12  2002                                        19.196522
# 13  2003                                        19.011848
# 14  2004                                        18.756522
# ...

# %%
male = pd.DataFrame(res1, columns=["schizophrenia","bipolar_disorder","eating_disorders", "anxiety_disorders", "drug_use_disorders", "depression", "alcohol_use_disorders" ,"Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"])
male.plot(x="schizophrenia", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="bipolar_disorder", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="eating_disorders", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="anxiety_disorders", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="drug_use_disorders", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="depression", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
male.plot(x="alcohol_use_disorders", y=["Average of Male suicide rate (age-standardized)", "Average of Female suicide rate (age-standardized)"],
        kind="line", figsize=(5, 5))
plt.grid()
plt.show()

# %%
gg = res1.copy()

# apply normalization techniques
for column in gg.columns:gg['schizophrenia'] = gg['schizophrenia'] / gg['schizophrenia'].abs().max()
for column in gg.columns:gg['Average of Male suicide rate (age-standardized)'] = gg['Average of Male suicide rate (age-standardized)'] / gg['Average of Male suicide rate (age-standardized)'].abs().max()
for column in gg.columns:gg['depression'] = gg['depression'] / gg['depression'].abs().max()


# view normalized data
gg
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                         0.929884
# 1   1991                                         0.936946
# 2   1992                                         0.951790
# 3   1993                                         0.978942
# 4   1994                                         0.996915
# 5   1995                                         1.000000
# 6   1996                                         0.986410
# 7   1997                                         0.980553
# 8   1998                                         0.978451
# 9   1999                                         0.971875
# 10  2000                                         0.968681
# 11  2001                                         0.961878
# 12  2002                                         0.954308
# 13  2003                                         0.945127
# 14  2004                                         0.932434
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt 
plt.xticks(rotation=90)
schizophrenia = gg['schizophrenia']
Male_suicide=gg['Average of Male suicide rate (age-standardized)']
depression=gg['depression']

plt.plot(gg.year, schizophrenia,color="red")
plt.plot(gg.year, Male_suicide,color="blue")
plt.plot(gg.year, depression,color="green")

plt.title('Average of depression prevalance in males vs year')
plt.xlabel('Year')
plt.legend(['schizophrenia', 'Male_suicide', 'depression'])
plt.grid()
plt.show()

# %%
df3 = pd.read_csv('marriage-rate-per-1000-inhabitants.csv')
df3 = df3.groupby(['year']).sum()
df3
# Out:
#       Crude_marriage_rate
# year
# 1920                 12.0
# 1921                 10.7
# 1922                 10.3
# 1923                 11.0
# 1924                 10.4
# ...                   ...
# 2014                259.1
# 2015                278.7
# 2016                271.0
# 2017                249.1
# 2018                  6.5
#
# [99 rows x 1 columns]

# %%
df1 = df1.groupby(['year']).sum()
df1
# Out:
#       Average of Male suicide rate (age-standardized)  \
# year
# 1990                                        18.705217
# 1991                                        18.847283
# 1992                                        19.145870
# 1993                                        19.692065
# 1994                                        20.053587
# 1995                                        20.115652
# 1996                                        19.842283
# 1997                                        19.724457
# 1998                                        19.682174
# 1999                                        19.549891
# 2000                                        19.485652
# 2001                                        19.348804
# 2002                                        19.196522
# 2003                                        19.011848
# 2004                                        18.756522
# 2005                                        18.714239
# ...

# %%
res2 = pd.merge(df3, df1, how='right', on=['year'])
res2
# Out:
#       Crude_marriage_rate  Average of Male suicide rate (age-standardized)  \
# year
# 1990           316.000000                                        18.705217
# 1991           291.700000                                        18.847283
# 1992           333.100000                                        19.145870
# 1993           319.600001                                        19.692065
# 1994           303.600000                                        20.053587
# 1995           851.800000                                        20.115652
# 1996           322.700001                                        19.842283
# 1997           302.699999                                        19.724457
# 1998           278.900000                                        19.682174
# 1999           301.600000                                        19.549891
# 2000           331.300001                                        19.485652
# ...

# %%
#Normalization

df_max_scaled = res2.copy()

# apply normalization techniques
for column in df_max_scaled.columns:df_max_scaled['Crude_marriage_rate'] = df_max_scaled['Crude_marriage_rate'] / df_max_scaled['Crude_marriage_rate'].abs().max()
for column in df_max_scaled.columns:df_max_scaled['Average of Male suicide rate (age-standardized)'] = df_max_scaled['Average of Male suicide rate (age-standardized)'] / df_max_scaled['Average of Male suicide rate (age-standardized)'].abs().max()
for column in df_max_scaled.columns:df_max_scaled['Average of Female suicide rate (age-standardized)'] = df_max_scaled['Average of Female suicide rate (age-standardized)'] / df_max_scaled['Average of Female suicide rate (age-standardized)'].abs().max()


# view normalized data
df_max_scaled
# Out:
#       Crude_marriage_rate  Average of Male suicide rate (age-standardized)  \
# year
# 1990             0.370979                                         0.929884
# 1991             0.342451                                         0.936946
# 1992             0.391054                                         0.951790
# 1993             0.375205                                         0.978942
# 1994             0.356422                                         0.996915
# 1995             1.000000                                         1.000000
# 1996             0.378845                                         0.986410
# 1997             0.355365                                         0.980553
# 1998             0.327424                                         0.978451
# 1999             0.354074                                         0.971875
# 2000             0.388941                                         0.968681
# ...

# %%
plt.xticks(rotation=90)
cmr = df_max_scaled['Crude_marriage_rate']
Male_suicide=df_max_scaled['Average of Male suicide rate (age-standardized)']
Female_suicide=df_max_scaled['Average of Female suicide rate (age-standardized)']

plt.plot(df_max_scaled.index, cmr,color="red")
plt.plot(df_max_scaled.index, Male_suicide,color="blue")
plt.plot(df_max_scaled.index, Female_suicide,color="green")

plt.title('Average of depression prevalance in males vs year')
plt.xlabel('Year')
plt.legend(['cmr', 'avg male suicide', 'avg female suicide'])
plt.grid()
plt.show()

# %%
df4 = pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
df4=df4.drop(['Average_of_Male_suicide_rate (age-standardized)'], axis=1)
df4=df4.groupby(['year']).sum()
df4
# Out:
#       Average_of_depression_prevalance_in_males
# year
# 1990                                   2.682156
# 1991                                   2.681672
# 1992                                   2.680720
# 1993                                   2.686673
# 1994                                   2.698425
# 1995                                   2.695155
# 1996                                   2.671866
# 1997                                   2.695919
# 1998                                   2.723878
# 1999                                   2.689029
# 2000                                   2.683809
# 2001                                   2.684277
# 2002                                   2.711238
# 2003                                   2.695115
# 2004                                   2.702497
# 2005                                   2.702982
# 2006                                   2.694818
# 2007                                   2.692649
# ...

# %%
res3 = pd.merge(df4, df1, how='right', on=['year'])
res3
# Out:
#       Average_of_depression_prevalance_in_males  \
# year
# 1990                                   2.682156
# 1991                                   2.681672
# 1992                                   2.680720
# 1993                                   2.686673
# 1994                                   2.698425
# 1995                                   2.695155
# 1996                                   2.671866
# 1997                                   2.695919
# 1998                                   2.723878
# 1999                                   2.689029
# 2000                                   2.683809
# 2001                                   2.684277
# 2002                                   2.711238
# 2003                                   2.695115
# 2004                                   2.702497
# 2005                                   2.702982
# 2006                                   2.694818
# 2007                                   2.692649
# ...

# %%
#Normalization

df_max_scaled1 = res3.copy()

# apply normalization techniques
for column in df_max_scaled1.columns:df_max_scaled1['Average_of_depression_prevalance_in_males'] = df_max_scaled1['Average_of_depression_prevalance_in_males'] / df_max_scaled1['Average_of_depression_prevalance_in_males'].abs().max()
for column in df_max_scaled1.columns:df_max_scaled1['Average of Male suicide rate (age-standardized)'] = df_max_scaled1['Average of Male suicide rate (age-standardized)'] / df_max_scaled1['Average of Male suicide rate (age-standardized)'].abs().max()
for column in df_max_scaled1.columns:df_max_scaled1['Average of Female suicide rate (age-standardized)'] = df_max_scaled1['Average of Female suicide rate (age-standardized)'] / df_max_scaled1['Average of Female suicide rate (age-standardized)'].abs().max()


# view normalized data
df_max_scaled1
# Out:
#       Average_of_depression_prevalance_in_males  \
# year
# 1990                                   0.984683
# 1991                                   0.984505
# 1992                                   0.984156
# 1993                                   0.986341
# 1994                                   0.990656
# 1995                                   0.989455
# 1996                                   0.980905
# 1997                                   0.989735
# 1998                                   1.000000
# 1999                                   0.987206
# 2000                                   0.985290
# 2001                                   0.985462
# 2002                                   0.995360
# 2003                                   0.989440
# 2004                                   0.992151
# 2005                                   0.992328
# 2006                                   0.989331
# 2007                                   0.988535
# ...

# %%
plt.xticks(rotation=90)
cmr = df_max_scaled1['Average_of_depression_prevalance_in_males']
Male_suicide=df_max_scaled1['Average of Male suicide rate (age-standardized)']
Female_suicide=df_max_scaled1['Average of Female suicide rate (age-standardized)']

plt.plot(df_max_scaled1.index, cmr,color="red")
plt.plot(df_max_scaled1.index, Male_suicide,color="blue")
plt.plot(df_max_scaled1.index, Female_suicide,color="green")

plt.title('Average of depression prevalance in males vs year')
plt.xlabel('Year')
plt.legend(['depression', 'avg male suicide', 'avg female suicide'])
plt.grid()
plt.show()

# %%
cc = pd.read_csv("marriage-rate-per-1000-inhabitants.csv")
cc=cc.groupby("year").sum()
cc = cc.iloc[70:98]
cc.head()
# Out:
#       Crude_marriage_rate
# year
# 1990           316.000000
# 1991           291.700000
# 1992           333.100000
# 1993           319.600001
# 1994           303.600000

# %%
res4 = pd.merge(df4, cc, how='right', on=['year'])
res4.head()
res4.corr()
# Out:
#                                            Average_of_depression_prevalance_in_males  \
# Average_of_depression_prevalance_in_males                                   1.000000
# Crude_marriage_rate                                                         0.169214
#
#                                            Crude_marriage_rate
# Average_of_depression_prevalance_in_males             0.169214
# Crude_marriage_rate                                   1.000000

# %%
df_max_scaled12 = res4.copy()

# apply normalization techniques
for column in df_max_scaled12.columns:df_max_scaled12['Crude_marriage_rate'] = df_max_scaled12['Crude_marriage_rate'] / df_max_scaled12['Crude_marriage_rate'].abs().max()
for column in df_max_scaled12.columns:df_max_scaled12['Average_of_depression_prevalance_in_males'] = df_max_scaled1['Average_of_depression_prevalance_in_males'] / df_max_scaled1['Average_of_depression_prevalance_in_males'].abs().max()


# view normalized data
df_max_scaled12.head()
# Out:
#       Average_of_depression_prevalance_in_males  Crude_marriage_rate
# year
# 1990                                   0.984683             0.370979
# 1991                                   0.984505             0.342451
# 1992                                   0.984156             0.391054
# 1993                                   0.986341             0.375205
# 1994                                   0.990656             0.356422

# %%
plt.xticks(rotation=90)
cmr = df_max_scaled12['Crude_marriage_rate']
Male_depression=df_max_scaled12['Average_of_depression_prevalance_in_males']

plt.plot(df_max_scaled12.index, cmr,color="red")
plt.plot(df_max_scaled12.index, Male_depression,color="blue")

plt.title('Average of depression prevalance in males vs year')
plt.xlabel('Year')
plt.legend(['Crude_marriage_rate', 'Average_of_depression_prevalance_in_males'])
plt.grid()
plt.show()

# %% [markdown]
# # Country with minimum average male suicide rate

# %%
df=pd.read_csv('prevalence_by_mental_and_substa.csv')
d = df[df.year==1995]
d["total"]=d["schizophrenia"] + d["bipolar_disorder"] + d["eating_disorders"] + d["anxiety_disorders"] + d["drug_use_disorders"] + d["depression"] + d["alcohol_use_disorders"]
d
# Out:
# /var/folders/01/858tkgy52j77xxqjvsnjjkdc0000gn/T/ipykernel_34762/459731238.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["total"]=d["schizophrenia"] + d["bipolar_disorder"] + d["eating_disorders"] + d["anxiety_disorders"] + d["drug_use_disorders"] + d["depression"] + d["alcohol_use_disorders"]
#                           entity      code  year  schizophrenia  \
# 5                    Afghanistan       AFG  1995       0.160076
# 33                       Albania       ALB  1995       0.193559
# 61                       Algeria       DZA  1995       0.192458
# 89                American Samoa       ASM  1995       0.249678
# 117         Andean Latin America       NaN  1995       0.195637
# ...

# %%
t = d[d.total == d["total"].max()]
t
# Out:
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903           0.47654
#
#       anxiety_disorders  drug_use_disorders  depression  \
# 2245           5.648279            1.678836    6.602754
#
#       alcohol_use_disorders      total
# 2245               3.489129  18.802194

# %%
mynmar = df.loc[(df['code']=='MMR') & (df['year']==2017)]
mynmar
values = mynmar.iloc[:, 3:10].copy()
labels = values.columns
values = values.squeeze()


fig, ax = plt.subplots()


ax.pie(values, labels=labels, autopct='%1.1f%%')


ax.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
