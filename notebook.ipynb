# %% [markdown]
# TEAM ID: D3
# SEM: 3
# DIV: D
# DEPARTMENT: COMPUTER SCIENCE

# %% [markdown]
# # PROJECT TITLE:WHY ARE SUICICDE RATE HIGH IN MALES

# %% [markdown]
# # Team Details:
# Aayushi Gupta-01fe20bcs207(423)
# Darshan Dixit-01fe20bcs215(431)
# Shreyas Jakati-01fe20bcs216(432)
# Shashank hosapeti-01fe20bcs197(413)

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn import preprocessing

# %% [markdown]
# # prevalence_by_mental_and_substa dataset

# %%
#prevalence_by_mental_and_substa dataset
df = pd.read_csv('./prevalence_by_mental_and_substa.csv')
df.head()
# Out:
#         entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 0  Afghanistan  AFG  1990       0.160560          0.697779          0.101855
# 1  Afghanistan  AFG  1991       0.160312          0.697961          0.099313
# 2  Afghanistan  AFG  1992       0.160135          0.698107          0.096692
# 3  Afghanistan  AFG  1993       0.160037          0.698257          0.094336
# 4  Afghanistan  AFG  1994       0.160022          0.698469          0.092439
#
#    anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 0           4.828830            1.677082    4.071831               0.672404
# 1           4.829740            1.684746    4.079531               0.671768
# 2           4.831108            1.694334    4.088358               0.670644
# 3           4.830864            1.705320    4.096190               0.669738
# 4           4.829423            1.716069    4.099582               0.669260

# %%
print("prevalence_by_mental_and_substa dataset contains",df.shape[0],"and ",df.shape[1],"number of rows and colums respectively")
# df.shape
# Out:
# prevalence_by_mental_and_substa dataset contains 6468 and  10 number of rows and colums respectively

# %%
# dataset description
df.describe()
# Out:
#               year  schizophrenia  bipolar_disorder  eating_disorders  \
# count  6468.000000    6468.000000       6468.000000       6468.000000
# mean   2003.500000       0.211644          0.719145          0.239998
# std       8.078372       0.044253          0.171589          0.158141
# min    1990.000000       0.146902          0.314535          0.073908
# 25%    1996.750000       0.181530          0.615532          0.122387
# 50%    2003.500000       0.199563          0.693134          0.182525
# 75%    2010.250000       0.236365          0.835063          0.292666
# max    2017.000000       0.375110          1.206597          0.943991
#
#        anxiety_disorders  drug_use_disorders   depression  \
# count        6468.000000         6468.000000  6468.000000
# mean            3.989921            0.862278     3.497654
# std             1.167526            0.460679     0.655859
# min             2.023393            0.383650     2.139903
# ...

# %%
# Nan valuses in prevalence_by_mental_and_substa dataset
any_nan_df = df[df.isna().any(axis=1)]
any_nan_df
# Out:
#                           entity code  year  schizophrenia  bipolar_disorder  \
# 112         Andean Latin America  NaN  1990       0.195471          0.870564
# 113         Andean Latin America  NaN  1991       0.195484          0.870876
# 114         Andean Latin America  NaN  1992       0.195497          0.871174
# 115         Andean Latin America  NaN  1993       0.195523          0.871482
# 116         Andean Latin America  NaN  1994       0.195569          0.871823
# ...                          ...  ...   ...            ...               ...
# 6351  Western Sub-Saharan Africa  NaN  2013       0.173905          0.635737
# 6352  Western Sub-Saharan Africa  NaN  2014       0.174254          0.636185
# 6353  Western Sub-Saharan Africa  NaN  2015       0.174616          0.636682
# 6354  Western Sub-Saharan Africa  NaN  2016       0.174980          0.637211
# 6355  Western Sub-Saharan Africa  NaN  2017       0.175340          0.637776
#
# ...

# %%
#number of Nan values in prevalence_by_mental_and_substa dataset
print('Looks like there are '+str(any_nan_df.shape[0])+' rows with atleast one NaN!')
# Out:
# Looks like there are 980 rows with atleast one NaN!

# %%
#number of Nan valuses in prevalence_by_mental_and_substa dataset
dataset = df
print(dataset.isnull().sum())
# Out:
# entity                     0
# code                     980
# Year                       0
# schizophrenia              0
# bipolar_disorder           0
# eating_disorders           0
# anxiety_disorders          0
# drug_use_disorders         0
# depression                 0
# alcohol_use_disorders      0
# dtype: int64

# %%
all_nan_df = df[df.isna().all(axis=1)]
all_nan_df.shape
all_nan_df
# Out:
# Empty DataFrame
# Columns: [entity, code, Year, schizophrenia, bipolar_disorder, eating_disorders, anxiety_disorders, drug_use_disorders, depression, alcohol_use_disorders]
# Index: []

# %%
print('And there are '+str(all_nan_df.shape[0])+' rows with all NaN\'s!')
# Out:
# And there are 0 rows with all NaN's!

# %%
# type of data in the given dataset
df.dtypes
# Out:
# entity                    object
# code                      object
# year                       int64
# schizophrenia            float64
# bipolar_disorder         float64
# eating_disorders         float64
# anxiety_disorders        float64
# drug_use_disorders       float64
# depression               float64
# alcohol_use_disorders    float64
# dtype: object

# %%
print("Country with MAXIMUM level of bipolar_disorder")
bip = df[df.bipolar_disorder == df['bipolar_disorder'].max()]
bip
# Out:
# Country with MAXIMUM level of bipolar_disorder
#            entity code  year  schizophrenia  bipolar_disorder  \
# 4027  New Zealand  NZL  2013       0.341031          1.206597
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 4027          0.665308            8.53867            2.036344    3.969718
#
#       alcohol_use_disorders
# 4027               1.956453

# %%
print("Country with MINIMUM level of bipolar_disorder")
bip1 = df[df.bipolar_disorder == df['bipolar_disorder'].min()]
bip1
# Out:
# Country with MINIMUM level of bipolar_disorder
#      entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 1260  China  CHN  1990       0.318924          0.314535          0.085918
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 1260           3.128626            1.147397    3.573966               0.981807

# %%
print("Country with MAXIMUM level of depression")
dep = df[df.depression == df["depression"].max()]
dep
# Out:
# Country with MAXIMUM level of depression
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903           0.47654
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 2245           5.648279            1.678836    6.602754               3.489129

# %%
print("Country with MINIMUM level of depression")
dep1 = df[df.depression == df["depression"].min()]
dep1
# Out:
# Country with MINIMUM level of depression
#      entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 28  Albania  ALB  1990       0.193413          0.695013          0.130782
#
#     anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 28           3.327587            0.497616    2.139903               1.709465

# %%
print("Country with MAXIMUM level of schizophrenia")
sch = df[df.schizophrenia == df["schizophrenia"].max()]
sch
# Out:
# Country with MAXIMUM level of schizophrenia
#            entity code  year  schizophrenia  bipolar_disorder  \
# 3992  Netherlands  NLD  2006        0.37511          0.947197
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 3992          0.409201           6.512405            0.937893    4.046277
#
#       alcohol_use_disorders
# 3992               0.722001

# %%
print("Country with MINIMUM level of schizophrenia")
sch = df[df.schizophrenia == df["schizophrenia"].min()]
sch
# Out:
# Country with MINIMUM level of schizophrenia
#           entity code  year  schizophrenia  bipolar_disorder  \
# 3866  Mozambique  MOZ  1992       0.146902          0.603562
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 3866          0.076041           3.591123            0.488752    3.767717
#
#       alcohol_use_disorders
# 3866               1.594383

# %%
print("Country with MAXIMUM level of eating_disorders")
eat = df[df.eating_disorders == df["eating_disorders"].max()]
eat
# Out:
# Country with MAXIMUM level of eating_disorders
#         entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 334  Australia  AUS  2016       0.363743          1.143669          0.943991
#
#      anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 334           6.589757            2.237198    4.659817               1.511465

# %%
print("Country with MINIMUM level of eating_disorders")
eat = df[df.eating_disorders == df["eating_disorders"].min()]
eat
# Out:
# Country with MINIMUM level of eating_disorders
#        entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 3893  Myanmar  MMR  1991       0.189887          0.500032          0.073908
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 3893           3.216425            0.554288    2.246085               0.837158

# %%
print("Country with MAXIMUM level of anxiety_disorders")
anx = df[df.anxiety_disorders == df["anxiety_disorders"].max()]
anx
# Out:
# Country with MAXIMUM level of anxiety_disorders
#            entity code  year  schizophrenia  bipolar_disorder  \
# 4016  New Zealand  NZL  2002       0.339223          1.195859
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 4016          0.635264            8.96733            2.141658    4.125419
#
#       alcohol_use_disorders
# 4016               1.447662

# %%
print("Country with MINIMUM level of anxiety_disorders")
anx = df[df.anxiety_disorders == df["anxiety_disorders"].min()]
anx
# Out:
# Country with MINIMUM level of anxiety_disorders
#        entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 6259  Vietnam  VNM  2005       0.235363          0.546672          0.103511
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 6259           2.023393            0.649577    2.923107               1.558684

# %%
print("Country with MAXIMUM level of alcohol_use_disorders")
alc = df[df.alcohol_use_disorders == df["alcohol_use_disorders"].max()]
alc
# Out:
# Country with MAXIMUM level of alcohol_use_disorders
#       entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 524  Belarus  BLR  2010       0.194892          0.698158           0.19208
#
#      anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 524           2.944119            0.782906    4.093854               5.474668

# %%
print("Country with MINIMUM level of alcohol_use_disorders")
alc = df[df.alcohol_use_disorders == df["alcohol_use_disorders"].min()]
alc
# Out:
# Country with MINIMUM level of alcohol_use_disorders
#      entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2833  Italy  ITA  1995       0.235932          0.949639          0.604477
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 2833           5.532503            1.281482    3.530343                0.44694

# %% [raw]
# comparing between randon countries

# %%
avg_dep = df["depression"].sum()/6468
print("average depression rate ",avg_dep)
# Out:
# average depression rate  3.497653585653159

# %%
avg_schizophrenia = df["schizophrenia"].sum()/6468
print("average schizophrenia rate ",avg_schizophrenia)
# Out:
# average schizophrenia rate  0.21164355081139133

# %%
avg_eating_disorders = df["eating_disorders"].sum()/6468
print("average eating disorders rate ",avg_eating_disorders)
# Out:
# average eating disorders rate  0.2399983609920943

# %%
avg_bipolar_disorder = df["bipolar_disorder"].sum()/6468
avg_bipolar_disorder
print("average bipolar disorder rate ",avg_bipolar_disorder)
# Out:
# average bipolar disorder rate  0.7191451949099932

# %%
avg_anxiety_disorders = df["anxiety_disorders"].sum()/6468
avg_anxiety_disorders
print("average anxiety disorder rate ",avg_anxiety_disorders)
# Out:
# average anxiety disorder rate  3.9899212964041744

# %%
avg_alcohol_use_disorders = df["alcohol_use_disorders"].sum()/6468
avg_alcohol_use_disorders
print("average alcohol disorder rate ",avg_alcohol_use_disorders)
# Out:
# average alcohol disorder rate  1.5858214134704773

# %%
bipolar = df.sort_values('bipolar_disorder',ascending=False)
bipolar_top = bipolar.head()
bipolar_top
# Out:
#            entity code  year  schizophrenia  bipolar_disorder  \
# 4027  New Zealand  NZL  2013       0.341031          1.206597
# 4026  New Zealand  NZL  2012       0.341054          1.206549
# 4028  New Zealand  NZL  2014       0.340994          1.206502
# 4025  New Zealand  NZL  2011       0.341082          1.206429
# 4029  New Zealand  NZL  2015       0.340990          1.206423
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 4027          0.665308           8.538670            2.036344    3.969718
# 4026          0.663944           8.537060            2.034724    3.974729
# 4028          0.667358           8.539198            2.037590    3.967374
# 4025          0.661753           8.534747            2.035388    3.980139
# 4029          0.669326           8.539694            2.040377    3.967735
#
#       alcohol_use_disorders
# 4027               1.956453
# 4026               1.896684
# 4028               2.016153
# 4025               1.836970
# ...

# %%
depression = df.sort_values('depression',ascending=False)
depression_top = depression.head()
depression_top
# Out:
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903          0.476540
# 2246  Greenland  GRL  1996       0.315904          0.591282          0.476873
# 2247  Greenland  GRL  1997       0.316404          0.591425          0.479072
# 2248  Greenland  GRL  1998       0.317109          0.591568          0.480106
# 2244  Greenland  GRL  1994       0.316124          0.590683          0.476551
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 2245           5.648279            1.678836    6.602754               3.489129
# 2246           5.651103            1.693140    6.601250               3.505568
# 2247           5.656238            1.727403    6.598258               3.526801
# 2248           5.659557            1.770310    6.586734               3.548203
# 2244           5.644656            1.678047    6.582469               3.471894

# %%
schizophrenia = df.sort_values('schizophrenia',ascending=True)
schizophrenia_top = schizophrenia.head()
schizophrenia_top
# Out:
#           entity code  year  schizophrenia  bipolar_disorder  \
# 3866  Mozambique  MOZ  1992       0.146902          0.603562
# 3867  Mozambique  MOZ  1993       0.146907          0.603639
# 3865  Mozambique  MOZ  1991       0.146938          0.603488
# 3868  Mozambique  MOZ  1994       0.146949          0.603732
# 3869  Mozambique  MOZ  1995       0.147017          0.603832
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 3866          0.076041           3.591123            0.488752    3.767717
# 3867          0.075732           3.596212            0.490872    3.772736
# 3865          0.076403           3.585056            0.485753    3.761645
# 3868          0.075595           3.600203            0.493057    3.779678
# 3869          0.075706           3.602771            0.494475    3.784766
#
#       alcohol_use_disorders
# 3866               1.594383
# 3867               1.597536
# 3865               1.590888
# 3868               1.600279
# ...

# %%
eating_disorders = df.sort_values('eating_disorders',ascending=False)
eating_disorders_top = eating_disorders.head()
eating_disorders_top
# Out:
#         entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 334  Australia  AUS  2016       0.363743          1.143669          0.943991
# 333  Australia  AUS  2015       0.364163          1.145130          0.943206
# 335  Australia  AUS  2017       0.363326          1.142097          0.943081
# 332  Australia  AUS  2014       0.364577          1.146475          0.941661
# 331  Australia  AUS  2013       0.364942          1.147593          0.939176
#
#      anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 334           6.589757            2.237198    4.659817               1.511465
# 333           6.595691            2.170634    4.696774               1.510434
# 335           6.584301            2.315142    4.623881               1.511935
# 332           6.602041            2.114377    4.731142               1.508926
# 331           6.608198            2.068835    4.759686               1.506864

# %%
anxiety_disorders = df.sort_values('anxiety_disorders',ascending=False)
anxiety_disorders_top = anxiety_disorders.head()
anxiety_disorders_top
# Out:
#            entity code  year  schizophrenia  bipolar_disorder  \
# 4016  New Zealand  NZL  2002       0.339223          1.195859
# 4017  New Zealand  NZL  2003       0.339718          1.197693
# 4015  New Zealand  NZL  2001       0.338835          1.194346
# 4018  New Zealand  NZL  2004       0.340177          1.199378
# 4014  New Zealand  NZL  2000       0.338677          1.193562
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 4016          0.635264           8.967330            2.141658    4.125419
# 4017          0.640880           8.966183            2.156798    4.126590
# 4015          0.630797           8.965461            2.128583    4.123757
# 4018          0.646286           8.962565            2.167622    4.126467
# 4014          0.627839           8.959512            2.120178    4.124330
#
#       alcohol_use_disorders
# 4016               1.447662
# 4017               1.450309
# 4015               1.447156
# 4018               1.454776
# ...

# %%
drug_use_disorders = df.sort_values('drug_use_disorders',ascending=False)
drug_use_disorders_top = drug_use_disorders.head()
drug_use_disorders_top
# Out:
#              entity code  year  schizophrenia  bipolar_disorder  \
# 6103  United States  USA  2017       0.333890          0.651236
# 6102  United States  USA  2016       0.334578          0.651569
# 4171  North America  NaN  2017       0.332040          0.657692
# 6101  United States  USA  2015       0.335243          0.651890
# 4170  North America  NaN  2016       0.332633          0.657948
#
#       eating_disorders  anxiety_disorders  drug_use_disorders  depression  \
# 6103          0.512844           6.635055            3.452476    4.835610
# 6102          0.517728           6.642099            3.353142    4.813114
# 4171          0.509470           6.490707            3.338079    4.752802
# 6101          0.522109           6.650662            3.262674    4.795954
# 4170          0.513733           6.496640            3.245661    4.730472
#
#       alcohol_use_disorders
# 6103               2.040087
# 6102               2.028263
# 4171               1.997606
# ...

# %%
depression = df.sort_values('depression',ascending=False)
depression_top = depression.head()
depression_top
# Out:
#          entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 2245  Greenland  GRL  1995       0.315753          0.590903          0.476540
# 2246  Greenland  GRL  1996       0.315904          0.591282          0.476873
# 2247  Greenland  GRL  1997       0.316404          0.591425          0.479072
# 2248  Greenland  GRL  1998       0.317109          0.591568          0.480106
# 2244  Greenland  GRL  1994       0.316124          0.590683          0.476551
#
#       anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 2245           5.648279            1.678836    6.602754               3.489129
# 2246           5.651103            1.693140    6.601250               3.505568
# 2247           5.656238            1.727403    6.598258               3.526801
# 2248           5.659557            1.770310    6.586734               3.548203
# 2244           5.644656            1.678047    6.582469               3.471894

# %%
alcohol_use_disorders = df.sort_values('alcohol_use_disorders',ascending=False)
alcohol_use_disorders_top = alcohol_use_disorders.head()
alcohol_use_disorders_top
# Out:
#       entity code  year  schizophrenia  bipolar_disorder  eating_disorders  \
# 524  Belarus  BLR  2010       0.194892          0.698158          0.192080
# 525  Belarus  BLR  2011       0.195331          0.698440          0.195576
# 526  Belarus  BLR  2012       0.195775          0.698711          0.198830
# 523  Belarus  BLR  2009       0.194306          0.697769          0.187940
# 527  Belarus  BLR  2013       0.196204          0.698947          0.201185
#
#      anxiety_disorders  drug_use_disorders  depression  alcohol_use_disorders
# 524           2.944119            0.782906    4.093854               5.474668
# 525           2.945178            0.784316    4.082054               5.473536
# 526           2.945942            0.785741    4.069614               5.467508
# 523           2.942467            0.780240    4.107442               5.461357
# 527           2.946482            0.786034    4.059205               5.455420

# %%
#plottt

# %%
Italy = df[df.entity == 'Italy']
Italy.alcohol_use_disorders
# Out:
# 2828    0.458408
# 2829    0.454951
# 2830    0.451861
# 2831    0.449365
# 2832    0.447662
# 2833    0.446940
# 2834    0.447098
# 2835    0.447723
# 2836    0.448558
# 2837    0.449360
# 2838    0.449900
# 2839    0.450155
# 2840    0.450356
# 2841    0.450590
# 2842    0.450926
# 2843    0.451417
# 2844    0.453432
# 2845    0.457413
# 2846    0.461949
# 2847    0.465679
# 2848    0.467220
# 2849    0.467204
# 2850    0.467127
# 2851    0.466905
# 2852    0.466450
# 2853    0.465702
# 2854    0.464585
# 2855    0.462937
# Name: alcohol_use_disorders, dtype: float64

# %%
Belarus = df[df.entity == 'Belarus']
Belarus.alcohol_use_disorders
# Out:
# 504    4.795118
# 505    4.889664
# 506    4.977548
# 507    5.054909
# 508    5.117567
# 509    5.161239
# 510    5.195849
# 511    5.231324
# 512    5.263432
# 513    5.288012
# 514    5.301741
# 515    5.309297
# 516    5.317841
# 517    5.326972
# 518    5.336839
# 519    5.346677
# 520    5.365402
# 521    5.397580
# 522    5.432642
# 523    5.461357
# 524    5.474668
# 525    5.473536
# 526    5.467508
# 527    5.455420
# 528    5.436959
# 529    5.412366
# 530    5.381010
# 531    5.342888
# Name: alcohol_use_disorders, dtype: float64

# %%
plt.bar(Belarus.year, Belarus.alcohol_use_disorders, color="blue")
plt.xlabel("year")
plt.ylabel("alcohol_use_disorders")
plt.title("Year-wise growth on death due to depression (first year = 100%)")
plt.show()

# %%
plt.bar(Italy.year, Italy.alcohol_use_disorders, color="red")
plt.xlabel("Year")
plt.ylabel("alcohol_use_disorders")
plt.title("Year-wise growth on death due to depression (first year = 100%)")
plt.show()

# %%
#column "code" dropped
df=df.drop(['code'], axis=1)
dataset1 = df
print(dataset1.isnull().sum())
# Out:
# entity                   0
# year                     0
# schizophrenia            0
# bipolar_disorder         0
# eating_disorders         0
# anxiety_disorders        0
# drug_use_disorders       0
# depression               0
# alcohol_use_disorders    0
# dtype: int64

# %% [markdown]
# # MALE VS FEMALE SUICIDE RATE

# %%
suiciderate=pd.read_csv('male-vs-female-suicide.csv')
suiciderate.head()
# Out:
#    year  Average of Male suicide rate (age-standardized)  \
# 0  1990                                        18.705217
# 1  1991                                        18.847283
# 2  1992                                        19.145870
# 3  1993                                        19.692065
# 4  1994                                        20.053587
#
#    Average of Female suicide rate (age-standardized)
# 0                                           6.978913
# 1                                           6.932283
# 2                                           6.966196
# 3                                           6.973043
# 4                                           6.957826

# %%
#dataset description 
suiciderate.describe()
# Out:
#               year  Average of Male suicide rate (age-standardized)  \
# count    28.000000                                        28.000000
# mean   2003.500000                                        18.380025
# std       8.225975                                         1.332996
# min    1990.000000                                        15.876739
# 25%    1996.750000                                        17.328234
# 50%    2003.500000                                        18.735380
# 75%    2010.250000                                        19.501712
# max    2017.000000                                        20.115652
#
#        Average of Female suicide rate (age-standardized)
# count                                          28.000000
# mean                                            6.015894
# std                                             0.791849
# min                                             4.712391
# 25%                                             5.332364
# ...

# %%
df = pd.read_csv('male-vs-female-suicide.csv')
df
# Out:
#     year  Average of Male suicide rate (age-standardized)  \
# 0   1990                                        18.705217
# 1   1991                                        18.847283
# 2   1992                                        19.145870
# 3   1993                                        19.692065
# 4   1994                                        20.053587
# 5   1995                                        20.115652
# 6   1996                                        19.842283
# 7   1997                                        19.724457
# 8   1998                                        19.682174
# 9   1999                                        19.549891
# 10  2000                                        19.485652
# 11  2001                                        19.348804
# 12  2002                                        19.196522
# 13  2003                                        19.011848
# 14  2004                                        18.756522
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df.year, df["Average of Male suicide rate (age-standardized)"], color="blue")
plt.plot(df.year, df["Average of Male suicide rate (age-standardized)"], color="red")
plt.legend(['Average of Male suicide rate', 'Average of Female suicide rate'])
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Average suicide rate (age-standardized)")
plt.title("Year-wise comparison of average male and female suicide rate")
plt.show()

# %%
dep=pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
plt.xticks(rotation=90)
Year = dep['year']
Depression=dep['Average_of_depression_prevalance_in_males']
plt.plot(Year, Depression,color="red",linewidth = '2.75')
plt.title('Average of depression prevalance in males vs year')
plt.xlabel('Year')
plt.ylabel('Average of depression prevalance in males')
plt.show()

# %% [markdown]
# # marriage-rate-per-1000-inhabitants

# %%
crude=pd.read_csv('marriage-rate-per-1000-inhabitants.csv')
# crude['Crude_marriage_rate_(per 1000 inhabitants)'].max()
crude.shape
# xx=crude[crude.Crude_marriage_rate_(per 1000 inhabitants)==59.0]
# m=crude['Crude_marriage_rate_(per 1000 inhabitants)'].min()
# m
# Out:
# (3251, 4)

# %%
#dataset description 
crude.describe()
# Out:
#               year  Crude_marriage_rate
# count  3251.000000          3251.000000
# mean   1989.635497             6.694802
# std      17.105366             2.637367
# min    1920.000000             0.200000
# 25%    1976.000000             5.100000
# 50%    1991.000000             6.500000
# 75%    2005.000000             7.950000
# max    2018.000000            59.000000

# %%
cr=crude[crude.year==1995]
cr
# Out:
#                    Entity Code  year  Crude_marriage_rate
# 34                Albania  ALB  1995             8.300000
# 55                Algeria  DZA  1995             5.500000
# 75               Anguilla  AIA  1995            19.700001
# 80    Antigua and Barbuda  ATG  1995            21.000000
# 83              Argentina  ARG  1995             4.300000
# ...                   ...  ...   ...                  ...
# 3107       United Kingdom  GBR  1995             5.600000
# 3202        United States  USA  1995             8.900000
# 3231              Uruguay  URY  1995             5.400000
# 3236           Uzbekistan  UZB  1995             7.500000
# 3243            Venezuela  VEN  1995             3.800000
#
# [124 rows x 4 columns]

# %%
gBar = crude.groupby(['Crude_marriage_rate', 'year'])
gBar.first()
# Out:
#                                                 Entity Code
# Crude_marriage_rate year
# 0.200000            1970                 Guinea-Bissau  GNB
#                     1971                 Guinea-Bissau  GNB
# 0.400000            1988         Sao Tome and Principe  STP
# 0.500000            2001                         Yemen  YEM
# 0.600000            2002                         Yemen  YEM
# ...                                                ...  ...
# 34.200001           1993  United States Virgin Islands  VIR
# 35.000000           1972                      Maldives  MDV
# 37.000000           1992                      Pitcairn  PCN
# 37.400002           2005                  Cook Islands  COK
# 59.000000           2007                  Cook Islands  COK
#
# [2135 rows x 2 columns]

# %%
x=crude['Crude_marriage_rate'].max()

# %%
#number of unique 
ll =crude['Entity'].unique()
ll.shape[0]
# Out:
# 183

# %%
#crude=crude.drop(['Entity', 'Code'], axis = 1)
crude=crude.groupby('year').sum()
crude
# Out:
#       Crude_marriage_rate
# year
# 1920                 12.0
# 1921                 10.7
# 1922                 10.3
# 1923                 11.0
# 1924                 10.4
# ...                   ...
# 2014                259.1
# 2015                278.7
# 2016                271.0
# 2017                249.1
# 2018                  6.5
#
# [99 rows x 1 columns]

# %%
c=crude.sort_values(by="Crude_marriage_rate",ascending=False)
# crhead
c.head(30)
# ig
# Out:
#       Crude_marriage_rate
# year
# 1970           996.400000
# 1985           958.199999
# 1995           851.800000
# 2005           778.000003
# 2006           618.199999
# 2004           480.400002
# 2007           445.400000
# 1972           404.999999
# 1971           368.700000
# 1980           354.400000
# 1983           348.700000
# 1976           347.300000
# 2003           346.300000
# 1973           342.600000
# 1975           340.800000
# 1969           340.600000
# 2008           339.600000
# 1974           337.300000
# 1968           337.100000
# 1967           336.300000
# 1986           334.000000
# 1989           333.900000
# 1992           333.100000
# 2000           331.300001
# 1987           330.600000
# 1964           329.800000
# 1979           329.300000
# 1977           327.700000
# 1978           324.900000
# 1966           324.800000

# %%
c=crude.sort_values(by="Crude_marriage_rate",ascending=False)
c
# Out:
#       Crude_marriage_rate
# year
# 1970           996.400000
# 1985           958.199999
# 1995           851.800000
# 2005           778.000003
# 2006           618.199999
# ...                   ...
# 1931             8.600000
# 1959             8.500000
# 1958             8.400000
# 1932             7.900000
# 2018             6.500000
#
# [99 rows x 1 columns]

# %% [markdown]
# # male-vs-female-suicide-with-depression-prevalance

# %%
#average male an deprrssion
dep=pd.read_csv('male-vs-female-suicide-with-depression-prevalance.csv')
dep
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 0   1990                                   2.682156
# 1   1991                                   2.681672
# 2   1992                                   2.680720
# 3   1993                                   2.686673
# 4   1994                                   2.698425
# 5   1995                                   2.695155
# 6   1996                                   2.671866
# 7   1997                                   2.695919
# 8   1998                                   2.723878
# 9   1999                                   2.689029
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 12  2002                                   2.711238
# 13  2003                                   2.695115
# 14  2004                                   2.702497
# 15  2005                                   2.702982
# 16  2006                                   2.694818
# ...

# %%
#dataset description 
dep.describe()
# Out:
#               year  Average_of_depression_prevalance_in_males  \
# count    28.000000                                  28.000000
# mean   2003.500000                                   2.688371
# std       8.225975                                   0.019857
# min    1990.000000                                   2.631965
# 25%    1996.750000                                   2.682035
# 50%    2003.500000                                   2.689537
# 75%    2010.250000                                   2.696545
# max    2017.000000                                   2.723878
#
#        Average_of_Male_suicide_rate (age-standardized)
# count                                        28.000000
# mean                                         18.806597
# std                                           1.368696
# min                                          16.422896
# 25%                                          17.627330
# 50%                                          19.212557
# ...

# %%
mx=dep.sort_values(by='Average_of_depression_prevalance_in_males',ascending=True)
mx
# Out:
#     year  Average_of_depression_prevalance_in_males  \
# 25  2015                                   2.631965
# 19  2009                                   2.651756
# 18  2008                                   2.654254
# 24  2014                                   2.669719
# 6   1996                                   2.671866
# 2   1992                                   2.680720
# 1   1991                                   2.681672
# 0   1990                                   2.682156
# 10  2000                                   2.683809
# 11  2001                                   2.684277
# 3   1993                                   2.686673
# 22  2012                                   2.688392
# 23  2013                                   2.688832
# 9   1999                                   2.689029
# 26  2016                                   2.690045
# 17  2007                                   2.692649
# 21  2011                                   2.692987
# ...

# %%
plt.xticks(rotation=90)
Year = dep['year'].tolist()
Depression=dep['Average_of_depression_prevalance_in_males'].tolist()
plt.plot(Year, Depression,color="red",linewidth = '2.5',marker='o')
plt.title('Average of depression prevalance in males vs year')
plt.xlabel('year')
plt.ylabel('Average_of_depression_prevalance_in_males')
plt.grid()
plt.show()
